# %%
import warnings
warnings.filterwarnings("ignore", category = FutureWarning)

import os
import keras
#import h5py
import librosa
import itertools
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict


from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import Input
from keras.layers import Dropout
from keras.models import Model
from keras.applications.vgg16 import VGG16
# Out:
# Using TensorFlow backend.

# %%
"""
@description: Method to split a song into multiple songs using overlapping windows
"""
def splitsongs(X, y, window = 0.1, overlap = 0.5):
    # Empty lists to hold our results
    temp_X = []
    temp_y = []

    # Get the input song array size
    xshape = X.shape[0]
    chunk = int(xshape*window)
    offset = int(chunk*(1.-overlap))
    
    # Split the song and create new ones on windows
    spsong = [X[i:i+chunk] for i in range(0, xshape - chunk + offset, offset)]
    for s in spsong:
        temp_X.append(s)
        temp_y.append(y)

    return np.array(temp_X), np.array(temp_y)

# %%
"""
@description: Method to convert a list of songs to a np array of melspectrograms
"""
def to_melspectrogram(songs, n_fft = 1024, hop_length = 512):
    # Transformation function
    melspec = lambda x: librosa.feature.melspectrogram(x, n_fft = n_fft,
        hop_length = hop_length)[:,:,np.newaxis]

    # map transformation of input songs to melspectrogram using log-scale
    tsongs = map(melspec, songs)
    return np.array(list(tsongs))

# %%
def read_data(src_dir, genres, song_samples, spec_format, debug = True):    
    # Empty array of dicts with the processed features from all files
    arr_specs = []
    arr_genres = []

    # Read files from the folders
    for x,_ in genres.items():
        folder = src_dir + x
        
        for root, subdirs, files in os.walk(folder):
            for file in files:
                # Read the audio file
                file_name = folder + "/" + file
                signal, sr = librosa.load(file_name)
                signal = signal[:song_samples]
                
                # Debug process
                if debug:
                    print("Reading file: {}".format(file_name))
                
                # Convert to dataset of spectograms/melspectograms
                signals, y = splitsongs(signal, genres[x])
                
                # Convert to "spec" representation
                specs = spec_format(signals)
                
                # Save files
                arr_genres.extend(y)
                arr_specs.extend(specs)
                
                
    return np.array(arr_specs), np.array(arr_genres)

# %%
# Parameters
gtzan_dir = './Data/genres/'
song_samples = 660000
genres = {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 
          'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %%
# Read the data
X, y = read_data(gtzan_dir, genres, song_samples, to_melspectrogram, debug=True)
np.save('x_gtzan_npy.npy', X)
np.save('y_gtzan_npy.npy', y)
# Out:
# Reading file: ./Data/genres/blues/blues.00088.wav
# Reading file: ./Data/genres/blues/blues.00091.wav
# Reading file: ./Data/genres/blues/blues.00023.wav
# Reading file: ./Data/genres/blues/blues.00024.wav
# Reading file: ./Data/genres/blues/blues.00070.wav
# Reading file: ./Data/genres/blues/blues.00053.wav
# Reading file: ./Data/genres/blues/blues.00085.wav
# Reading file: ./Data/genres/blues/blues.00033.wav
# Reading file: ./Data/genres/blues/blues.00019.wav
# Reading file: ./Data/genres/blues/blues.00031.wav
# Reading file: ./Data/genres/blues/blues.00020.wav
# Reading file: ./Data/genres/blues/blues.00001.wav
# Reading file: ./Data/genres/blues/blues.00046.wav
# Reading file: ./Data/genres/blues/blues.00098.wav
# Reading file: ./Data/genres/blues/blues.00017.wav
# Reading file: ./Data/genres/blues/blues.00009.wav
# Reading file: ./Data/genres/blues/blues.00040.wav
# Reading file: ./Data/genres/blues/blues.00074.wav
# Reading file: ./Data/genres/blues/blues.00086.wav
# Reading file: ./Data/genres/blues/blues.00068.wav
# Reading file: ./Data/genres/blues/blues.00075.wav
# Reading file: ./Data/genres/blues/blues.00078.wav
# Reading file: ./Data/genres/blues/blues.00062.wav
# Reading file: ./Data/genres/blues/blues.00094.wav
# Reading file: ./Data/genres/blues/blues.00081.wav
# Reading file: ./Data/genres/blues/blues.00035.wav
# Reading file: ./Data/genres/blues/blues.00012.wav
# Reading file: ./Data/genres/blues/blues.00072.wav
# Reading file: ./Data/genres/blues/blues.00090.wav
# Reading file: ./Data/genres/blues/blues.00021.wav
# Reading file: ./Data/genres/blues/blues.00037.wav
# Reading file: ./Data/genres/blues/blues.00058.wav
# Reading file: ./Data/genres/blues/blues.00049.wav
# Reading file: ./Data/genres/blues/blues.00026.wav
# Reading file: ./Data/genres/blues/blues.00022.wav
# Reading file: ./Data/genres/blues/blues.00060.wav
# Reading file: ./Data/genres/blues/blues.00055.wav
# Reading file: ./Data/genres/blues/blues.00050.wav
# Reading file: ./Data/genres/blues/blues.00006.wav
# Reading file: ./Data/genres/blues/blues.00064.wav
# Reading file: ./Data/genres/blues/blues.00045.wav
# Reading file: ./Data/genres/blues/blues.00063.wav
# Reading file: ./Data/genres/blues/blues.00036.wav
# Reading file: ./Data/genres/blues/blues.00052.wav
# Reading file: ./Data/genres/blues/blues.00007.wav
# Reading file: ./Data/genres/blues/blues.00038.wav
# Reading file: ./Data/genres/blues/blues.00014.wav
# Reading file: ./Data/genres/blues/blues.00032.wav
# Reading file: ./Data/genres/blues/blues.00095.wav
# Reading file: ./Data/genres/blues/blues.00097.wav
# Reading file: ./Data/genres/blues/blues.00002.wav
# Reading file: ./Data/genres/blues/blues.00080.wav
# Reading file: ./Data/genres/blues/blues.00028.wav
# Reading file: ./Data/genres/blues/blues.00076.wav
# Reading file: ./Data/genres/blues/blues.00016.wav
# Reading file: ./Data/genres/blues/blues.00096.wav
# Reading file: ./Data/genres/blues/blues.00030.wav
# Reading file: ./Data/genres/blues/blues.00056.wav
# Reading file: ./Data/genres/blues/blues.00004.wav
# Reading file: ./Data/genres/blues/blues.00051.wav
# Reading file: ./Data/genres/blues/blues.00092.wav
# Reading file: ./Data/genres/blues/blues.00087.wav
# Reading file: ./Data/genres/blues/blues.00048.wav
# Reading file: ./Data/genres/blues/blues.00027.wav
# Reading file: ./Data/genres/blues/blues.00039.wav
# Reading file: ./Data/genres/blues/blues.00083.wav
# Reading file: ./Data/genres/blues/blues.00034.wav
# Reading file: ./Data/genres/blues/blues.00093.wav
# Reading file: ./Data/genres/blues/blues.00065.wav
# Reading file: ./Data/genres/blues/blues.00029.wav
# Reading file: ./Data/genres/blues/blues.00061.wav
# Reading file: ./Data/genres/blues/blues.00013.wav
# Reading file: ./Data/genres/blues/blues.00003.wav
# Reading file: ./Data/genres/blues/blues.00008.wav
# Reading file: ./Data/genres/blues/blues.00071.wav
# Reading file: ./Data/genres/blues/blues.00041.wav
# Reading file: ./Data/genres/blues/blues.00042.wav
# Reading file: ./Data/genres/blues/blues.00011.wav
# Reading file: ./Data/genres/blues/blues.00057.wav
# Reading file: ./Data/genres/blues/blues.00077.wav
# Reading file: ./Data/genres/blues/blues.00010.wav
# Reading file: ./Data/genres/blues/blues.00047.wav
# Reading file: ./Data/genres/blues/blues.00054.wav
# Reading file: ./Data/genres/blues/blues.00005.wav
# Reading file: ./Data/genres/blues/blues.00059.wav
# Reading file: ./Data/genres/blues/blues.00015.wav
# Reading file: ./Data/genres/blues/blues.00079.wav
# Reading file: ./Data/genres/blues/blues.00084.wav
# Reading file: ./Data/genres/blues/blues.00043.wav
# Reading file: ./Data/genres/blues/blues.00073.wav
# Reading file: ./Data/genres/blues/blues.00089.wav
# Reading file: ./Data/genres/blues/blues.00069.wav
# Reading file: ./Data/genres/blues/blues.00000.wav
# Reading file: ./Data/genres/blues/blues.00082.wav
# Reading file: ./Data/genres/blues/blues.00066.wav
# Reading file: ./Data/genres/blues/blues.00018.wav
# Reading file: ./Data/genres/blues/blues.00025.wav
# Reading file: ./Data/genres/blues/blues.00044.wav
# Reading file: ./Data/genres/blues/blues.00067.wav
# Reading file: ./Data/genres/classical/classical.00008.wav
# Reading file: ./Data/genres/classical/classical.00067.wav
# Reading file: ./Data/genres/classical/classical.00033.wav
# Reading file: ./Data/genres/classical/classical.00071.wav
# Reading file: ./Data/genres/classical/classical.00048.wav
# Reading file: ./Data/genres/classical/classical.00038.wav
# Reading file: ./Data/genres/classical/classical.00076.wav
# Reading file: ./Data/genres/classical/classical.00055.wav
# Reading file: ./Data/genres/classical/classical.00020.wav
# Reading file: ./Data/genres/classical/classical.00056.wav
# Reading file: ./Data/genres/classical/classical.00091.wav
# Reading file: ./Data/genres/classical/classical.00050.wav
# Reading file: ./Data/genres/classical/classical.00022.wav
# Reading file: ./Data/genres/classical/classical.00042.wav
# Reading file: ./Data/genres/classical/classical.00031.wav
# Reading file: ./Data/genres/classical/classical.00075.wav
# Reading file: ./Data/genres/classical/classical.00049.wav
# Reading file: ./Data/genres/classical/classical.00041.wav
# Reading file: ./Data/genres/classical/classical.00039.wav
# Reading file: ./Data/genres/classical/classical.00051.wav
# Reading file: ./Data/genres/classical/classical.00003.wav
# Reading file: ./Data/genres/classical/classical.00095.wav
# Reading file: ./Data/genres/classical/classical.00057.wav
# Reading file: ./Data/genres/classical/classical.00015.wav
# Reading file: ./Data/genres/classical/classical.00030.wav
# Reading file: ./Data/genres/classical/classical.00092.wav
# Reading file: ./Data/genres/classical/classical.00036.wav
# Reading file: ./Data/genres/classical/classical.00045.wav
# Reading file: ./Data/genres/classical/classical.00019.wav
# Reading file: ./Data/genres/classical/classical.00062.wav
# Reading file: ./Data/genres/classical/classical.00025.wav
# Reading file: ./Data/genres/classical/classical.00063.wav
# Reading file: ./Data/genres/classical/classical.00094.wav
# Reading file: ./Data/genres/classical/classical.00070.wav
# Reading file: ./Data/genres/classical/classical.00089.wav
# Reading file: ./Data/genres/classical/classical.00004.wav
# Reading file: ./Data/genres/classical/classical.00093.wav
# Reading file: ./Data/genres/classical/classical.00096.wav
# Reading file: ./Data/genres/classical/classical.00040.wav
# Reading file: ./Data/genres/classical/classical.00016.wav
# Reading file: ./Data/genres/classical/classical.00005.wav
# Reading file: ./Data/genres/classical/classical.00060.wav
# Reading file: ./Data/genres/classical/classical.00080.wav
# Reading file: ./Data/genres/classical/classical.00013.wav
# Reading file: ./Data/genres/classical/classical.00069.wav
# Reading file: ./Data/genres/classical/classical.00068.wav
# Reading file: ./Data/genres/classical/classical.00009.wav
# Reading file: ./Data/genres/classical/classical.00006.wav
# Reading file: ./Data/genres/classical/classical.00065.wav
# Reading file: ./Data/genres/classical/classical.00053.wav
# Reading file: ./Data/genres/classical/classical.00002.wav
# Reading file: ./Data/genres/classical/classical.00058.wav
# Reading file: ./Data/genres/classical/classical.00047.wav
# Reading file: ./Data/genres/classical/classical.00029.wav
# Reading file: ./Data/genres/classical/classical.00034.wav
# Reading file: ./Data/genres/classical/classical.00054.wav
# Reading file: ./Data/genres/classical/classical.00011.wav
# Reading file: ./Data/genres/classical/classical.00072.wav
# Reading file: ./Data/genres/classical/classical.00074.wav
# Reading file: ./Data/genres/classical/classical.00018.wav
# Reading file: ./Data/genres/classical/classical.00023.wav
# Reading file: ./Data/genres/classical/classical.00052.wav
# Reading file: ./Data/genres/classical/classical.00000.wav
# Reading file: ./Data/genres/classical/classical.00032.wav
# Reading file: ./Data/genres/classical/classical.00098.wav
# Reading file: ./Data/genres/classical/classical.00086.wav
# Reading file: ./Data/genres/classical/classical.00007.wav
# Reading file: ./Data/genres/classical/classical.00043.wav
# Reading file: ./Data/genres/classical/classical.00012.wav
# Reading file: ./Data/genres/classical/classical.00027.wav
# Reading file: ./Data/genres/classical/classical.00078.wav
# Reading file: ./Data/genres/classical/classical.00064.wav
# Reading file: ./Data/genres/classical/classical.00079.wav
# Reading file: ./Data/genres/classical/classical.00059.wav
# Reading file: ./Data/genres/classical/classical.00061.wav
# Reading file: ./Data/genres/classical/classical.00014.wav
# Reading file: ./Data/genres/classical/classical.00084.wav
# Reading file: ./Data/genres/classical/classical.00010.wav
# Reading file: ./Data/genres/classical/classical.00026.wav
# Reading file: ./Data/genres/classical/classical.00077.wav
# Reading file: ./Data/genres/classical/classical.00017.wav
# Reading file: ./Data/genres/classical/classical.00044.wav
# Reading file: ./Data/genres/classical/classical.00085.wav
# Reading file: ./Data/genres/classical/classical.00087.wav
# Reading file: ./Data/genres/classical/classical.00066.wav
# Reading file: ./Data/genres/classical/classical.00001.wav
# Reading file: ./Data/genres/classical/classical.00082.wav
# Reading file: ./Data/genres/classical/classical.00081.wav
# Reading file: ./Data/genres/classical/classical.00035.wav
# Reading file: ./Data/genres/classical/classical.00021.wav
# Reading file: ./Data/genres/classical/classical.00028.wav
# Reading file: ./Data/genres/classical/classical.00037.wav
# Reading file: ./Data/genres/classical/classical.00097.wav
# Reading file: ./Data/genres/classical/classical.00024.wav
# Reading file: ./Data/genres/classical/classical.00088.wav
# Reading file: ./Data/genres/classical/classical.00090.wav
# Reading file: ./Data/genres/classical/classical.00073.wav
# Reading file: ./Data/genres/classical/classical.00046.wav
# Reading file: ./Data/genres/classical/classical.00083.wav
# Reading file: ./Data/genres/country/country.00054.wav
# Reading file: ./Data/genres/country/country.00055.wav
# Reading file: ./Data/genres/country/country.00037.wav
# Reading file: ./Data/genres/country/country.00049.wav
# Reading file: ./Data/genres/country/country.00051.wav
# Reading file: ./Data/genres/country/country.00014.wav
# Reading file: ./Data/genres/country/country.00005.wav
# Reading file: ./Data/genres/country/country.00002.wav
# Reading file: ./Data/genres/country/country.00093.wav
# Reading file: ./Data/genres/country/country.00094.wav
# Reading file: ./Data/genres/country/country.00019.wav
# Reading file: ./Data/genres/country/country.00082.wav
# Reading file: ./Data/genres/country/country.00032.wav
# Reading file: ./Data/genres/country/country.00073.wav
# Reading file: ./Data/genres/country/country.00075.wav
# Reading file: ./Data/genres/country/country.00053.wav
# Reading file: ./Data/genres/country/country.00017.wav
# Reading file: ./Data/genres/country/country.00036.wav
# Reading file: ./Data/genres/country/country.00090.wav
# Reading file: ./Data/genres/country/country.00046.wav
# Reading file: ./Data/genres/country/country.00003.wav
# Reading file: ./Data/genres/country/country.00070.wav
# Reading file: ./Data/genres/country/country.00066.wav
# Reading file: ./Data/genres/country/country.00044.wav
# Reading file: ./Data/genres/country/country.00045.wav
# Reading file: ./Data/genres/country/country.00018.wav
# Reading file: ./Data/genres/country/country.00062.wav
# Reading file: ./Data/genres/country/country.00001.wav
# Reading file: ./Data/genres/country/country.00050.wav
# Reading file: ./Data/genres/country/country.00028.wav
# Reading file: ./Data/genres/country/country.00088.wav
# Reading file: ./Data/genres/country/country.00040.wav
# Reading file: ./Data/genres/country/country.00065.wav
# Reading file: ./Data/genres/country/country.00035.wav
# Reading file: ./Data/genres/country/country.00015.wav
# Reading file: ./Data/genres/country/country.00061.wav
# Reading file: ./Data/genres/country/country.00004.wav
# Reading file: ./Data/genres/country/country.00085.wav
# Reading file: ./Data/genres/country/country.00008.wav
# Reading file: ./Data/genres/country/country.00024.wav
# Reading file: ./Data/genres/country/country.00074.wav
# Reading file: ./Data/genres/country/country.00034.wav
# Reading file: ./Data/genres/country/country.00038.wav
# Reading file: ./Data/genres/country/country.00027.wav
# Reading file: ./Data/genres/country/country.00098.wav
# Reading file: ./Data/genres/country/country.00071.wav
# Reading file: ./Data/genres/country/country.00041.wav
# Reading file: ./Data/genres/country/country.00011.wav
# Reading file: ./Data/genres/country/country.00089.wav
# Reading file: ./Data/genres/country/country.00072.wav
# Reading file: ./Data/genres/country/country.00087.wav
# Reading file: ./Data/genres/country/country.00067.wav
# Reading file: ./Data/genres/country/country.00023.wav
# Reading file: ./Data/genres/country/country.00048.wav
# Reading file: ./Data/genres/country/country.00031.wav
# Reading file: ./Data/genres/country/country.00078.wav
# Reading file: ./Data/genres/country/country.00058.wav
# Reading file: ./Data/genres/country/country.00021.wav
# Reading file: ./Data/genres/country/country.00083.wav
# Reading file: ./Data/genres/country/country.00091.wav
# Reading file: ./Data/genres/country/country.00059.wav
# Reading file: ./Data/genres/country/country.00079.wav
# Reading file: ./Data/genres/country/country.00010.wav
# Reading file: ./Data/genres/country/country.00000.wav
# Reading file: ./Data/genres/country/country.00080.wav
# Reading file: ./Data/genres/country/country.00042.wav
# Reading file: ./Data/genres/country/country.00039.wav
# Reading file: ./Data/genres/country/country.00043.wav
# Reading file: ./Data/genres/country/country.00020.wav
# Reading file: ./Data/genres/country/country.00029.wav
# Reading file: ./Data/genres/country/country.00096.wav
# Reading file: ./Data/genres/country/country.00060.wav
# Reading file: ./Data/genres/country/country.00030.wav
# Reading file: ./Data/genres/country/country.00081.wav
# Reading file: ./Data/genres/country/country.00022.wav
# Reading file: ./Data/genres/country/country.00033.wav
# Reading file: ./Data/genres/country/country.00069.wav
# Reading file: ./Data/genres/country/country.00097.wav
# Reading file: ./Data/genres/country/country.00052.wav
# Reading file: ./Data/genres/country/country.00056.wav
# Reading file: ./Data/genres/country/country.00063.wav
# Reading file: ./Data/genres/country/country.00092.wav
# Reading file: ./Data/genres/country/country.00012.wav
# Reading file: ./Data/genres/country/country.00047.wav
# Reading file: ./Data/genres/country/country.00016.wav
# Reading file: ./Data/genres/country/country.00057.wav
# Reading file: ./Data/genres/country/country.00076.wav
# Reading file: ./Data/genres/country/country.00009.wav
# Reading file: ./Data/genres/country/country.00013.wav
# Reading file: ./Data/genres/country/country.00026.wav
# Reading file: ./Data/genres/country/country.00007.wav
# Reading file: ./Data/genres/country/country.00086.wav
# Reading file: ./Data/genres/country/country.00025.wav

# %%
X = np.load('x_gtzan_npy.npy')
y = np.load('y_gtzan_npy.npy')

# %%
X
# Out:
# array([], dtype=float64)
